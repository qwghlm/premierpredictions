# %% [markdown]
# ## Predicting Premier League Results
#
# Can we do it? Probably not. But anyway.
#
# Setup imports etc. first

# %%
import os
import pandas as pd
from IPython.display import display
from pandas.api.types import is_string_dtype

from fastai.tabular.transform import add_datepart

# %% [markdown]
# First, load the raw data

# %%
PATH = "data/"
pd.set_option("display.max_rows", 40)

raw_dataframe = pd.read_csv(f'{PATH}EPL_Set.csv', low_memory=False, parse_dates=["Date"])
display(raw_dataframe)
# Out:
#      Div       Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0     E0 1993-08-14      Arsenal        Coventry     0     3   A   NaN   NaN
# 1     E0 1993-08-14  Aston Villa             QPR     4     1   H   NaN   NaN
# 2     E0 1993-08-14      Chelsea       Blackburn     1     2   A   NaN   NaN
# 3     E0 1993-08-14    Liverpool  Sheffield Weds     2     0   H   NaN   NaN
# 4     E0 1993-08-14     Man City           Leeds     1     1   D   NaN   NaN
# ...   ..        ...          ...             ...   ...   ...  ..   ...   ...
# 9659  E0 2018-05-13    Newcastle         Chelsea     3     0   H   1.0   0.0
# 9660  E0 2018-05-13  Southampton        Man City     0     1   A   0.0   0.0
# 9661  E0 2018-05-13      Swansea           Stoke     1     2   A   1.0   2.0
# 9662  E0 2018-05-13    Tottenham       Leicester     5     4   H   1.0   2.0
# 9663  E0 2018-05-13     West Ham         Everton     3     1   H   1.0   0.0
#
#       HTR   Season
# 0     NaN  1993-94
# 1     NaN  1993-94
# 2     NaN  1993-94
# 3     NaN  1993-94
# 4     NaN  1993-94
# ...   ...      ...
# 9659    H  2017-18
# 9660    D  2017-18
# 9661    A  2017-18
# 9662    A  2017-18
# 9663    H  2017-18
#
# [9664 rows x 11 columns]

# %% [markdown]
# Now let's remove data we do not need (we don't want half-time data, as we want to be able to predict before a game has even started

# %%
cleaned_dataframe = raw_dataframe.drop(["Div", "HTHG", "HTAG", "HTR"], axis=1)
display(cleaned_dataframe)

os.makedirs('tmp', exist_ok=True)
cleaned_dataframe.to_feather('tmp/epl-cleaned')
# Out:
#            Date     HomeTeam        AwayTeam  FTHG  FTAG FTR   Season
# 0    1993-08-14      Arsenal        Coventry     0     3   A  1993-94
# 1    1993-08-14  Aston Villa             QPR     4     1   H  1993-94
# 2    1993-08-14      Chelsea       Blackburn     1     2   A  1993-94
# 3    1993-08-14    Liverpool  Sheffield Weds     2     0   H  1993-94
# 4    1993-08-14     Man City           Leeds     1     1   D  1993-94
# ...         ...          ...             ...   ...   ...  ..      ...
# 9659 2018-05-13    Newcastle         Chelsea     3     0   H  2017-18
# 9660 2018-05-13  Southampton        Man City     0     1   A  2017-18
# 9661 2018-05-13      Swansea           Stoke     1     2   A  2017-18
# 9662 2018-05-13    Tottenham       Leicester     5     4   H  2017-18
# 9663 2018-05-13     West Ham         Everton     3     1   H  2017-18
#
# [9664 rows x 7 columns]

# %% [markdown]
# Now let's add derived data - calculate each team's form and matchday

# %%
import math
import numpy as np

augmented_dataframe = pd.read_feather('tmp/epl-cleaned')
add_datepart(augmented_dataframe, "Date")
augmented_dataframe = augmented_dataframe.drop(["Elapsed"], axis=1)

def form_score(results, length, default_value=0):
    """
    Calculate the recent form of this team, given a list of results and the # of games asked for
    """
    if not results.size:
        return default_value
    return sum(results[-length:])/len(results[-length:])

K = 16

def elo_score(R_home, R_away, result):
    """
    Calculates the Elo score for the home & away teams in a match
    Based on Elo with two modifications:
     - Expected home & away adjusted for home advantage
     - Goal difference taken into account
    https://www.eloratings.net/about
    """
        
    Q_home = 10**((R_home + 50)/400)
    Q_away = 10**((R_away - 50)/400)
    
    E_home = Q_home/(Q_home + Q_away)
    E_away = Q_away/(Q_home + Q_away)
    
    if result > 0:
        S_home = 1
        S_away = 0
    elif result == 0:
        S_home = 0.5
        S_away = 0.5
    elif result < 0:
        S_home = 0
        S_away = 1
        
    gd = abs(result)
    if gd < 2:
        k = K
    elif gd < 4:
        k = K*(1 + gd/4)
    else:
        k = K*(1.75 + (gd - 3)/8)
    
    R_home = R_home + k*(S_home - E_home)
    R_away = R_away + k*(S_away - E_away)
    return (R_home, R_away)

    
FORM_LENGTH = 10

matchdays = {}
elo = {}
home_form = {}
away_form = {}

for (i, row) in augmented_dataframe.iterrows():
        
    # Get teams
    home_team = row["HomeTeam"]
    away_team = row["AwayTeam"]
    
    # Get each team's respective matchday, form, and Elo score
    home_matchday = matchdays.get((home_team, row["Season"]), 1)
    away_matchday = matchdays.get((away_team, row["Season"]), 1)
    
    home_elo = elo.get(home_team, 1500 if row["Season"] == "1993-94" else 1400)
    away_elo = elo.get(away_team, 1500 if row["Season"] == "1993-94" else 1400)
    
    home_team_form = home_form.get(home_team, [])
    away_team_form = away_form.get(away_team, [])
    
    # Update the current row with these stats
    
    augmented_dataframe.at[i, "HomeMatchday"] = home_matchday
    augmented_dataframe.at[i, "AwayMatchday"] = away_matchday
        
    augmented_dataframe.at[i, "HomeElo"] = home_elo
    augmented_dataframe.at[i, "AwayElo"] = away_elo

    augmented_dataframe.at[i, "HomeForm"] = sum(home_team_form[-10:])
    augmented_dataframe.at[i, "AwayForm"] = sum(away_team_form[-10:])
    
    # Update the stats
    
    matchdays[(home_team, row["Season"])] = home_matchday + 1
    matchdays[(away_team, row["Season"])] = away_matchday + 1

    new_home_elo, new_away_elo = elo_score(home_elo, away_elo, row["FTHG"] - row["FTAG"])
    elo[home_team] = new_home_elo
    elo[away_team] = new_away_elo
    
    home_form[home_team] = home_team_form + [(new_home_elo - home_elo)]
    away_form[away_team] = away_team_form + [(new_away_elo - away_elo)]
            
augmented_dataframe = augmented_dataframe.drop(["Season"], axis=1)
augmented_dataframe.to_feather('tmp/epl-augmented')

display(augmented_dataframe)
# Out:
#          HomeTeam        AwayTeam  FTHG  FTAG FTR  Year  Month  Week  Day  \
# 0         Arsenal        Coventry     0     3   A  1993      8    32   14
# 1     Aston Villa             QPR     4     1   H  1993      8    32   14
# 2         Chelsea       Blackburn     1     2   A  1993      8    32   14
# 3       Liverpool  Sheffield Weds     2     0   H  1993      8    32   14
# 4        Man City           Leeds     1     1   D  1993      8    32   14
# ...           ...             ...   ...   ...  ..   ...    ...   ...  ...
# 9659    Newcastle         Chelsea     3     0   H  2018      5    19   13
# 9660  Southampton        Man City     0     1   A  2018      5    19   13
# 9661      Swansea           Stoke     1     2   A  2018      5    19   13
# 9662    Tottenham       Leicester     5     4   H  2018      5    19   13
# 9663     West Ham         Everton     3     1   H  2018      5    19   13
#
#       Dayofweek  ...  Is_quarter_end  Is_quarter_start  Is_year_end  \
# 0             5  ...           False             False        False
# 1             5  ...           False             False        False
# 2             5  ...           False             False        False
# 3             5  ...           False             False        False
# 4             5  ...           False             False        False
# ...         ...  ...             ...               ...          ...
# 9659          6  ...           False             False        False
# 9660          6  ...           False             False        False
# 9661          6  ...           False             False        False
# 9662          6  ...           False             False        False
# 9663          6  ...           False             False        False
#
#       Is_year_start  HomeMatchday  AwayMatchday      HomeElo      AwayElo  \
# 0             False           1.0           1.0  1500.000000  1500.000000
# 1             False           1.0           1.0  1500.000000  1500.000000
# 2             False           1.0           1.0  1500.000000  1500.000000
# 3             False           1.0           1.0  1500.000000  1500.000000
# 4             False           1.0           1.0  1500.000000  1500.000000
# ...             ...           ...           ...          ...          ...
# 9659          False          38.0          38.0  1444.778743  1701.977359
# 9660          False          38.0          38.0  1467.668590  1827.466509
# 9661          False          38.0          38.0  1430.460516  1418.054330
# 9662          False          38.0          38.0  1749.140418  1510.624895
# 9663          False          38.0          38.0  1471.569113  1540.087785
#
#        HomeForm   AwayForm
# 0      0.000000   0.000000
# 1      0.000000   0.000000
# 2      0.000000   0.000000
# 3      0.000000   0.000000
# 4      0.000000   0.000000
# ...         ...        ...
# 9659  11.539939  -6.661626
# 9660 -38.956622  31.722641
# 9661  19.085539  -1.054051
# 9662   6.923503   4.689006
# 9663 -16.958307  -8.656256
#
# [9664 rows x 23 columns]

# %% [markdown]
# Now, let's have a go at classifying the data:

# %%
from sklearn import preprocessing
from sklearn.ensemble import forest, RandomForestClassifier

def split_vals(a, n):
    return a[:n].copy(), a[n:].copy()

final_dataframe = pd.read_feather('tmp/epl-augmented')

# Label results
result_encoder = preprocessing.LabelEncoder()
result_encoder.fit(final_dataframe.FTR)
final_dataframe.FTR = result_encoder.transform(final_dataframe.FTR)

# Label team names
team_encoder = preprocessing.LabelEncoder()
team_encoder.fit(final_dataframe.HomeTeam)
final_dataframe.HomeTeam = team_encoder.transform(final_dataframe.HomeTeam)
final_dataframe.AwayTeam = team_encoder.transform(final_dataframe.AwayTeam)

# Drop result, and H/A goals from the data
START_OFFSET = 110
END_OFFSET = 380

source_dataframe = final_dataframe.drop(["FTR", "FTHG", "FTAG"], axis=1)
training_size = len(source_dataframe) - START_OFFSET - END_OFFSET

source_train, source_valid = split_vals(source_dataframe[START_OFFSET:], training_size)
result_train, result_valid = split_vals(augmented_dataframe.FTR[START_OFFSET:], training_size)

# %% [markdown]
# We need to redefine the RF sampling here as fastai v1 doesn't have them

# %%
def set_rf_samples(n):
    forest._generate_sample_indices = (lambda rs, n_samples:
            forest.check_random_state(rs).randint(0, n_samples, n))
    
def reset_rf_samples():
    forest._generate_sample_indices = (lambda rs, n_samples:
        forest.check_random_state(rs).randint(0, n_samples, n_samples))

# %% [markdown]
# Now, finally, we can run the classifier

# %%
reset_rf_samples()
set_rf_samples(2000)

classifier = RandomForestClassifier(n_jobs=-1, n_estimators=1000, max_features=0.5, min_samples_leaf=3, oob_score=True)
# %time classifier.fit(source_train, result_train)

print ("""
CLASSIFICATION:

Training data score: {}
Validation data score: {}
Out-of-bag score: {}""".format(
    classifier.score(source_train, result_train),
    classifier.score(source_valid, result_valid),
    classifier.oob_score_,
))
# Out:
# CPU times: user 12.4 s, sys: 449 ms, total: 12.8 s
# Wall time: 4.1 s
#
# CLASSIFICATION:
#
# Training data score: 0.7109221713538261
# Validation data score: 0.5394736842105263
# Out-of-bag score: 0.5089383039023326

# %% [markdown]
# ## Baseline
#
# Without any Elo data - just teams and dates, validation score is about `0.51`.
#
# ## Current model
#
# With random forest, using form, goals for & against & Elo score combined, accuracy of about `0.57`

# %% [markdown]
# ## TODOs
#
# * Add results since 1981 (when three points for a win was introduced)
# * Use weighted average of Elo form?

# %%
odds_dataframe = pd.read_csv(f'{PATH}2017-18-odds.csv', low_memory=False, parse_dates=["Date"])

# Transform the odds dataframe correctly
odds_dataframe["HomeTeam"] = team_encoder.transform(odds_dataframe["HomeTeam"])
odds_dataframe["AwayTeam"] = team_encoder.transform(odds_dataframe["AwayTeam"])
odds_dataframe = odds_dataframe.filter(["Date", "HomeTeam", "AwayTeam", "FTR", 
                                        "B365H", "B365D", "B365A",
                                        "LBH", "LBD", "LBA",
                                        "WHH", "WHD", "WHA",])

predictions = classifier.predict_proba(source_valid)
confidence_columns = ["Confidence{}".format(n) for n in classifier.classes_]
confidence_dataframe = pd.DataFrame(predictions, columns=confidence_columns)

validation_dataframe = source_valid.copy().reset_index(drop=True)
validation_dataframe["Prediction"] = classifier.predict(validation_dataframe)
validation_dataframe = pd.concat([validation_dataframe, confidence_dataframe], axis=1)
validation_dataframe = pd.merge(validation_dataframe, odds_dataframe, on=["HomeTeam", "AwayTeam"])
validation_dataframe["HomeTeam"] = team_encoder.inverse_transform(validation_dataframe["HomeTeam"])
validation_dataframe["AwayTeam"] = team_encoder.inverse_transform(validation_dataframe["AwayTeam"])

# %%
STAKE = 10

def calculate_bet_return(stake, prediction, odds, outcome):
    if outcome == prediction:
        winnings = odds * stake
    else:
        winnings = 0
    return winnings

# 

def make_home_bets(row, provider):
    winnings = calculate_bet_return(STAKE, "H", row[f"{provider}H"], row.FTR)
    return (STAKE, winnings - STAKE)

def make_draw_bets(row, provider):
    winnings = calculate_bet_return(STAKE, "D", row[f"{provider}D"], row.FTR)
    return (STAKE, winnings - STAKE)

def make_away_bets(row, provider):
    winnings = calculate_bet_return(STAKE, "A", row[f"{provider}D"], row.FTR)
    return (STAKE, winnings - STAKE)

def make_favourite_bets(row, provider):
    possibilities = [(row[f"{provider}{outcome}"], outcome) for outcome in ("H", "D", "A")]
    odds, prediction = sorted(possibilities)[0]
    winnings = calculate_bet_return(STAKE, prediction, odds, row.FTR)
    return (STAKE, winnings - STAKE)

def make_recommended_bets(row, provider):
    possibilities = [(row[f"Confidence{outcome}"], outcome) for outcome in ("H", "D", "A")]
    _, prediction = sorted(possibilities)[-1]
    odds = row[f"{provider}{prediction}"]
    winnings = calculate_bet_return(STAKE, prediction, odds, row.FTR)
    return (STAKE, winnings - STAKE)

def make_value_bets(row, provider):

    total_stake = 0
    total_winnings = 0

    for outcome in ("H", "D", "A"):
        B = row[f"{provider}{outcome}"] - 1
        P = row[f"Confidence{outcome}"]
        Q = 1 - P

        stake = 10 * STAKE * (B*P - Q)/B

        if stake > 0:
            total_stake += stake
            total_winnings += calculate_bet_return(stake, outcome, B + 1, row.FTR)

    return (total_stake, total_winnings - total_stake)

def make_most_likely_bets(row, provider):
    winnings = calculate_bet_return(STAKE, row.Prediction, row[f"{provider}{row.Prediction}"], row.FTR)
    return (STAKE, winnings - STAKE)

print("EVALUATION:")

for provider in ("B365", "LB", "WH", ):
    for bet in (
#         make_home_bets,
#         make_draw_bets,
#         make_away_bets,
        make_favourite_bets,
        make_recommended_bets,
        make_value_bets,
    ):

        validation_dataframe["Stake"] = validation_dataframe.apply(lambda r: bet(r, provider)[0], axis=1)
        validation_dataframe["Profit"] = validation_dataframe.apply(lambda r: bet(r, provider)[1], axis=1)

        print ("""
        With {} & {}, from a total stake of £{}, we get a profit of £{}
        """.format(
            bet.__name__,
            provider,
            validation_dataframe["Stake"].sum(),
            validation_dataframe["Profit"].sum(),
        ))
    print("-"*32)

display(validation_dataframe)
# Out:
# EVALUATION:
#
#         With make_favourite_bets & B365, from a total stake of £3800, we get a profit of £-195.69999999999993
#
#
#         With make_recommended_bets & B365, from a total stake of £3800, we get a profit of £-175.89999999999998
#
#
#         With make_value_bets & B365, from a total stake of £3722.7083271761717, we get a profit of £127.64958220328718
#
# --------------------------------
#
#         With make_favourite_bets & LB, from a total stake of £3800, we get a profit of £-231.69999999999996
#
#
#         With make_recommended_bets & LB, from a total stake of £3800, we get a profit of £-239.0
#
#
#         With make_value_bets & LB, from a total stake of £3060.39421177016, we get a profit of £-73.30818364755065
#
# --------------------------------
#
#         With make_favourite_bets & WH, from a total stake of £3800, we get a profit of £-176.79999999999998
#
#
#         With make_recommended_bets & WH, from a total stake of £3800, we get a profit of £-187.79999999999998
#
#
#         With make_value_bets & WH, from a total stake of £3289.710942696207, we get a profit of £28.296131191450918
#
# --------------------------------
#            HomeTeam      AwayTeam  Year  Month  Week  Day  Dayofweek  \
# 0           Arsenal     Leicester  2017     11    45    8          2
# 1          Brighton      Man City  2017     12    49    8          4
# 2           Chelsea       Burnley  2017     12    49    8          4
# 3    Crystal Palace  Huddersfield  2017     12    49    8          4
# 4           Everton         Stoke  2017     12    49    8          4
# ..              ...           ...   ...    ...   ...  ...        ...
# 375       Newcastle       Chelsea  2018      5    19   13          6
# 376     Southampton      Man City  2018      5    19   13          6
# 377         Swansea         Stoke  2018      5    19   13          6
# 378       Tottenham     Leicester  2018      5    19   13          6
# 379        West Ham       Everton  2018      5    19   13          6
#
#      Dayofyear  Is_month_end  Is_month_start  ...  B365D  B365A    LBH   LBD  \
# 0          312         False           False  ...   4.50   6.50   1.44  4.40
# 1          342         False           False  ...   5.50   1.33  10.00  5.00
# 2          342         False           False  ...   6.50  15.00   1.25  5.75
# 3          342         False           False  ...   3.60   5.00   1.80  3.40
# 4          342         False           False  ...   3.80   5.75   1.67  3.60
# ..         ...           ...             ...  ...    ...    ...    ...   ...
# 375        133         False           False  ...   4.20   1.60   5.50  3.90
# 376        133         False           False  ...   5.00   1.39   7.00  4.60
# 377        133         False           False  ...   3.79   4.20   1.87  3.60
# 378        133         False           False  ...   6.00   9.00   1.30  5.50
# 379        133         False           False  ...   3.50   3.00   2.30  3.40
#
#        LBA    WHH   WHD    WHA      Stake     Profit
# 0     6.50   1.53  4.20   6.00   1.927031  -1.927031
# 1     1.30  10.00  4.80   1.33  12.270006 -12.270006
# 2    15.00   1.25  5.50  13.00   0.738165   8.857976
# 3     4.60   1.80  3.30   5.00  18.309375  73.237500
# 4     5.25   1.70  3.50   5.50   7.803462  -7.803462
# ..     ...    ...   ...    ...        ...        ...
# 375   1.60   6.50  4.00   1.57   9.135602  39.439306
# 376   1.40   8.50  4.50   1.40  12.807563 -12.807563
# 377   4.00   1.91  3.75   4.00   1.882222   5.646667
# 378   9.50   1.30  6.00   9.00   4.167661  -4.167661
# 379   3.00   2.40  3.30   3.10   2.933798  -2.933798
#
# [380 rows x 37 columns]
